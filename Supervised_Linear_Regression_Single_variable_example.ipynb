# %%
import pandas as pd
import seaborn as sns 
# seaborn for data visualization
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\91937\Desktop\Machine Learning Tutorials\Superived_Training_testing_basic_example.csv")

df
# Out:
#    Age  Premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
sns.lmplot(x='Age',y='Premium',data=df)

# %%
reg = linear_model.LinearRegression()

reg.fit(df[['Age']],df[['Premium']])
# Out:
# LinearRegression()

# %%
reg.predict([[21]])
# Out:
# C:\Python11\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[13480.]])

# %%
reg.predict([[19]])
# Out:
# C:\Python11\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[9920.]])

# %%
reg.coef_
# Out:
# array([[1780.]])

# %%
reg.intercept_
# Out:
# array([-23900.])
